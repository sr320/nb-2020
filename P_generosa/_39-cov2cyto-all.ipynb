# %% [markdown]
# ## Taking the coverage file from an alignments -destrand.

# %%
pwd
# Out:
# u'/Users/sr320/git-repos/nb-2019/P_generosa'

# %%
# !ls /Volumes/Serine/wd/19-11-05/
# Out:
# PgALL.74.CpG_report.merged_CpG_evidence.cov      Pg_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# PgALL.74.CpG_report.txt                          genome
# PgALL.CpG_report.merged_CpG_evidence.cov         v074
# PgALL.CpG_report.txt

# %%
ls /Volumes/Serine/wd/19-12-17/
# Out:
# bismark_coverage_files/     bismark_coverage_files.zip

# %%
# !head /Volumes/Serine/wd/19-12-17/EPI-41_S38_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# Out:
# Scaffold_01	54	54	0	0	1
# Scaffold_01	72	72	0	0	1
# Scaffold_01	96	96	0	0	1
# Scaffold_01	2084	2084	0	0	1
# Scaffold_01	2154	2154	0	0	1
# Scaffold_01	2187	2187	0	0	1
# Scaffold_01	2196	2196	0	0	1
# Scaffold_01	2509	2509	0	0	2
# Scaffold_01	2554	2554	0	0	1
# Scaffold_01	2588	2588	0	0	1

# %% [markdown]
# ## have 2 prepared genomes

# %%
# !/Applications/bioinfo/Bismark_v0.20.0/bismark_genome_preparation \
--verbose \
--path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/ \
/Volumes/Serine/wd/19-11-05/
# Out:
# Path to genome folder specified as: /Volumes/Serine/wd/19-11-05/
# Aligner to be used: Bowtie 2 (default)
# Writing bisulfite genomes out into a single MFA (multi FastA) file
#
# Bismark Genome Preparation - Step I: Preparing folders
#
# Path to Bowtie 2 specified: /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/
# Bisulfite Genome Indexer version v0.20.0 (last modified 26 April 2018)
# Created Bisulfite Genome folder /Volumes/Serine/wd/19-11-05/Bisulfite_Genome/
# Created Bisulfite Genome folder /Volumes/Serine/wd/19-11-05/Bisulfite_Genome/CT_conversion/
# Created Bisulfite Genome folder /Volumes/Serine/wd/19-11-05/Bisulfite_Genome/GA_conversion/
#
# Step I - Prepare genome folders - completed
#
#
# Bismark Genome Preparation - Step II: Bisulfite converting reference genome
#
# conversions performed:
# chromosome	C->T	G->A
# Scaffold_01	12767429	12765526
# Scaffold_02	10088811	10062918
# Scaffold_03	8199278	8194496
# Scaffold_04	9161562	9161987
# Scaffold_05	9498414	9497714
# ...

# %%
# !/Applications/bioinfo/Bismark_v0.20.0/bismark_genome_preparation \
--verbose \
--path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/ \
/Volumes/Serine/wd/19-11-05/v074/
# Out:
# Path to genome folder specified as: /Volumes/Serine/wd/19-11-05/v074/
# Aligner to be used: Bowtie 2 (default)
# Writing bisulfite genomes out into a single MFA (multi FastA) file
#
# Bismark Genome Preparation - Step I: Preparing folders
#
# Path to Bowtie 2 specified: /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/
# Bisulfite Genome Indexer version v0.20.0 (last modified 26 April 2018)
# Created Bisulfite Genome folder /Volumes/Serine/wd/19-11-05/v074/Bisulfite_Genome/
# Created Bisulfite Genome folder /Volumes/Serine/wd/19-11-05/v074/Bisulfite_Genome/CT_conversion/
# Created Bisulfite Genome folder /Volumes/Serine/wd/19-11-05/v074/Bisulfite_Genome/GA_conversion/
#
# Step I - Prepare genome folders - completed
#
#
# Bismark Genome Preparation - Step II: Bisulfite converting reference genome
#
# conversions performed:
# chromosome	C->T	G->A
# PGA_scaffold1__77_contigs__length_89643857	12767429	12765526
# PGA_scaffold2__36_contigs__length_69596280	10088811	10062918
# ...

# %% [markdown]
# ## Cov2cyt

# %%
# !find /Volumes/Serine/wd/19-12-17/bismark_coverage_files/*cov.gz \
| xargs basename -s _R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov.gz \
| xargs -I{} /Applications/bioinfo/Bismark_v0.20.0/coverage2cytosine \
--genome_folder /Volumes/Serine/wd/19-11-05/genome/ \
-o /Volumes/Serine/wd/19-12-17/{} \
--merge_CpG \
/Volumes/Serine/wd/19-12-17/bismark_coverage_files/{}_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov.gz
# Out:
# Summary of parameters for genome-wide cytosine report:
# ...
# Coverage infile:				/Volumes/Serine/wd/19-12-17/bismark_coverage_files/EPI-103_S27_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov.gz
# Output directory:				><
# Parent directory:				>/Users/sr320/git-repos/nb-2019/P_generosa/<
# Genome directory:				>/Volumes/Serine/wd/19-11-05/genome/<
# CX context:					no (CpG context only, default)
# Pooling CpG top/bottom strand evidence:		yes
# Genome coordinates used:			1-based (default)
# GZIP compression:				no
# Split by chromosome:				no
#
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/19-11-05/genome/
#
# chr Scaffold_01 (89643857 bp)
# chr Scaffold_02 (69596280 bp)
# chr Scaffold_03 (57743597 bp)
# chr Scaffold_04 (65288255 bp)
# chr Scaffold_05 (67248332 bp)
# chr Scaffold_06 (61759565 bp)
# chr Scaffold_07 (43120122 bp)
# chr Scaffold_08 (61151155 bp)
# chr Scaffold_09 (38581958 bp)
# chr Scaffold_10 (53961475 bp)
# ...

# %%
# !ls -lh /Volumes/Serine/wd/19-11-05/
# Out:
# total 6055968
# -rw-r--r--  1 sr320  staff     0B Nov  5 20:18 PgALL.CpG_report.merged_CpG_evidence.cov
# -rw-r--r--  1 sr320  staff   1.0G Nov  5 20:18 PgALL.CpG_report.txt
# -rw-r--r--@ 1 sr320  staff   1.9G Nov  5 19:10 Pg_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# drwxr-xr-x  5 sr320  staff   170B Nov  5 20:07 genome
# drwxr-xr-x  2 sr320  staff    68B Nov  5 20:09 v074

# %%
# !head /Volumes/Serine/wd/19-11-05/PgALL.CpG_report.txt
# Out:
# Scaffold_01	4	+	0	0	CG	CGC
# Scaffold_01	5	-	0	0	CG	CGC
# Scaffold_01	18	+	0	0	CG	CGG
# Scaffold_01	19	-	0	0	CG	CGG
# Scaffold_01	54	+	0	0	CG	CGT
# Scaffold_01	55	-	0	0	CG	CGG
# Scaffold_01	72	+	0	0	CG	CGA
# Scaffold_01	73	-	0	0	CG	CGC
# Scaffold_01	96	+	0	0	CG	CGC
# Scaffold_01	97	-	0	0	CG	CGG

# %%
# !/Applications/bioinfo/Bismark_v0.20.0/coverage2cytosine \
--genome_folder /Volumes/Serine/wd/19-11-05/v074 \
-o /Volumes/Serine/wd/19-11-05/PgALL.74 \
--merge_CpG \
/Volumes/Serine/wd/19-11-05/Pg_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# Out:
# Summary of parameters for genome-wide cytosine report:
# ...
# Coverage infile:				/Volumes/Serine/wd/19-11-05/Pg_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# Output directory:				><
# Parent directory:				>/Users/sr320/git-repos/nb-2019/P_generosa/<
# Genome directory:				>/Volumes/Serine/wd/19-11-05/v074/<
# CX context:					no (CpG context only, default)
# Pooling CpG top/bottom strand evidence:		yes
# Genome coordinates used:			1-based (default)
# GZIP compression:				no
# Split by chromosome:				no
#
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/19-11-05/v074/
#
# chr PGA_scaffold1__77_contigs__length_89643857 (89643857 bp)
# chr PGA_scaffold2__36_contigs__length_69596280 (69596280 bp)
# chr PGA_scaffold3__111_contigs__length_57743597 (57743597 bp)
# chr PGA_scaffold4__129_contigs__length_65288255 (65288255 bp)
# chr PGA_scaffold5__109_contigs__length_67248332 (67248332 bp)
# ...

# %%
# !ls -lh /Volumes/Serine/wd/19-11-05/
# Out:
# total 12338208
# -rw-r--r--  1 sr320  staff   1.1G Nov  5 21:00 PgALL.74.CpG_report.merged_CpG_evidence.cov
# -rw-r--r--  1 sr320  staff   1.9G Nov  5 20:58 PgALL.74.CpG_report.txt
# -rw-r--r--  1 sr320  staff     0B Nov  5 20:18 PgALL.CpG_report.merged_CpG_evidence.cov
# -rw-r--r--  1 sr320  staff   1.0G Nov  5 20:18 PgALL.CpG_report.txt
# -rw-r--r--@ 1 sr320  staff   1.9G Nov  5 19:10 Pg_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# drwxr-xr-x  5 sr320  staff   170B Nov  5 20:07 genome
# drwxr-xr-x  4 sr320  staff   136B Nov  5 20:20 v074

# %%
# !head /Volumes/Serine/wd/19-11-05/PgALL.74.CpG_report.merged_CpG_evidence.cov
# Out:
# PGA_scaffold1__77_contigs__length_89643857	4	5	50.000000	1	1
# PGA_scaffold1__77_contigs__length_89643857	18	19	11.111111	1	8
# PGA_scaffold1__77_contigs__length_89643857	54	55	3.125000	1	31
# PGA_scaffold1__77_contigs__length_89643857	72	73	2.777778	1	35
# PGA_scaffold1__77_contigs__length_89643857	96	97	2.040816	1	48
# PGA_scaffold1__77_contigs__length_89643857	119	120	0.000000	0	48
# PGA_scaffold1__77_contigs__length_89643857	193	194	0.000000	0	43
# PGA_scaffold1__77_contigs__length_89643857	202	203	0.000000	0	48
# PGA_scaffold1__77_contigs__length_89643857	209	210	0.000000	0	54
# PGA_scaffold1__77_contigs__length_89643857	213	214	0.000000	0	57

# %%
# !cat /Volumes/Serine/wd/19-11-05/PgALL.74.CpG_report.merged_CpG_evidence.cov \
| awk '{if ($5+$6 >= 10) { print $1, $2, $3, $4, $5, $6 }}' | head
# Out:
# PGA_scaffold1__77_contigs__length_89643857 54 55 3.125000 1 31
# PGA_scaffold1__77_contigs__length_89643857 72 73 2.777778 1 35
# PGA_scaffold1__77_contigs__length_89643857 96 97 2.040816 1 48
# PGA_scaffold1__77_contigs__length_89643857 119 120 0.000000 0 48
# PGA_scaffold1__77_contigs__length_89643857 193 194 0.000000 0 43
# PGA_scaffold1__77_contigs__length_89643857 202 203 0.000000 0 48
# PGA_scaffold1__77_contigs__length_89643857 209 210 0.000000 0 54
# PGA_scaffold1__77_contigs__length_89643857 213 214 0.000000 0 57
# PGA_scaffold1__77_contigs__length_89643857 221 222 0.000000 0 62
# PGA_scaffold1__77_contigs__length_89643857 238 239 1.315789 1 75
# awk: write error on /dev/stdout
#  input record number 605, file
#  source line number 1
# cat: stdout: Broken pipe

# %%
# !cat /Volumes/Serine/wd/19-11-05/PgALL.74.CpG_report.merged_CpG_evidence.cov | cut -f 1 | sort | uniq
# Out:
# PGA_scaffold10__49_contigs__length_53961475
# PGA_scaffold11__79_contigs__length_51449921
# PGA_scaffold12__71_contigs__length_50438331
# PGA_scaffold13__52_contigs__length_44396874
# PGA_scaffold14__91_contigs__length_45393038
# PGA_scaffold15__101_contigs__length_47938513
# PGA_scaffold16__33_contigs__length_31980953
# PGA_scaffold17__51_contigs__length_34923512
# PGA_scaffold18__69_contigs__length_27737463
# PGA_scaffold1__77_contigs__length_89643857
# PGA_scaffold2__36_contigs__length_69596280
# PGA_scaffold3__111_contigs__length_57743597
# PGA_scaffold4__129_contigs__length_65288255
# PGA_scaffold5__109_contigs__length_67248332
# PGA_scaffold6__104_contigs__length_61759565
# PGA_scaffold7__69_contigs__length_43120122
# PGA_scaffold8__63_contigs__length_61151155
# PGA_scaffold9__45_contigs__length_38581958

# %%
# !cat /Volumes/Serine/wd/19-11-05/PgALL.74.CpG_report.merged_CpG_evidence.cov \
| sed 's/PGA_scaffold10__49_contigs__length_53961475/Scaffold_10/g' \
| sed 's/PGA_scaffold11__79_contigs__length_51449921/Scaffold_11/g' \
| sed 's/PGA_scaffold12__71_contigs__length_50438331/Scaffold_12/g' \
| sed 's/PGA_scaffold13__52_contigs__length_44396874/Scaffold_13/g' \
| sed 's/PGA_scaffold14__91_contigs__length_45393038/Scaffold_14/g' \
| sed 's/PGA_scaffold15__101_contigs__length_47938513/Scaffold_15/g' \
| sed 's/PGA_scaffold16__33_contigs__length_31980953/Scaffold_16/g' \
| sed 's/PGA_scaffold17__51_contigs__length_34923512/Scaffold_17/g' \
| sed 's/PGA_scaffold18__69_contigs__length_27737463/Scaffold_18/g' \
| sed 's/PGA_scaffold1__77_contigs__length_89643857/Scaffold_01/g' \
| sed 's/PGA_scaffold2__36_contigs__length_69596280/Scaffold_02/g' \
| sed 's/PGA_scaffold3__111_contigs__length_57743597/Scaffold_03/g' \
| sed 's/PGA_scaffold4__129_contigs__length_65288255/Scaffold_04/g' \
| sed 's/PGA_scaffold5__109_contigs__length_67248332/Scaffold_05/g' \
| sed 's/PGA_scaffold6__104_contigs__length_61759565/Scaffold_06/g' \
| sed 's/PGA_scaffold7__69_contigs__length_43120122/Scaffold_07/g' \
| sed 's/PGA_scaffold8__63_contigs__length_61151155/Scaffold_08/g' \
| sed 's/PGA_scaffold9__45_contigs__length_38581958/Scaffold_09/g' \
| cut -f 1 | sort | uniq
# Out:
# Scaffold_01
# Scaffold_02
# Scaffold_03
# Scaffold_04
# Scaffold_05
# Scaffold_06
# Scaffold_07
# Scaffold_08
# Scaffold_09
# Scaffold_10
# Scaffold_11
# Scaffold_12
# Scaffold_13
# Scaffold_14
# Scaffold_15
# Scaffold_16
# Scaffold_17
# Scaffold_18

# %%
# !cat /Volumes/Serine/wd/19-11-05/PgALL.74.CpG_report.merged_CpG_evidence.cov \
| sed 's/PGA_scaffold10__49_contigs__length_53961475/Scaffold_10/g' \
| sed 's/PGA_scaffold11__79_contigs__length_51449921/Scaffold_11/g' \
| sed 's/PGA_scaffold12__71_contigs__length_50438331/Scaffold_12/g' \
| sed 's/PGA_scaffold13__52_contigs__length_44396874/Scaffold_13/g' \
| sed 's/PGA_scaffold14__91_contigs__length_45393038/Scaffold_14/g' \
| sed 's/PGA_scaffold15__101_contigs__length_47938513/Scaffold_15/g' \
| sed 's/PGA_scaffold16__33_contigs__length_31980953/Scaffold_16/g' \
| sed 's/PGA_scaffold17__51_contigs__length_34923512/Scaffold_17/g' \
| sed 's/PGA_scaffold18__69_contigs__length_27737463/Scaffold_18/g' \
| sed 's/PGA_scaffold1__77_contigs__length_89643857/Scaffold_01/g' \
| sed 's/PGA_scaffold2__36_contigs__length_69596280/Scaffold_02/g' \
| sed 's/PGA_scaffold3__111_contigs__length_57743597/Scaffold_03/g' \
| sed 's/PGA_scaffold4__129_contigs__length_65288255/Scaffold_04/g' \
| sed 's/PGA_scaffold5__109_contigs__length_67248332/Scaffold_05/g' \
| sed 's/PGA_scaffold6__104_contigs__length_61759565/Scaffold_06/g' \
| sed 's/PGA_scaffold7__69_contigs__length_43120122/Scaffold_07/g' \
| sed 's/PGA_scaffold8__63_contigs__length_61151155/Scaffold_08/g' \
| sed 's/PGA_scaffold9__45_contigs__length_38581958/Scaffold_09/g' \
| awk '{if ($5+$6 >= 10) { print $1, "\t", $2, "\t", $3, "\t", $4}}' | head
# Out:
# Scaffold_01 	 54 	 55 	 3.125000
# Scaffold_01 	 72 	 73 	 2.777778
# Scaffold_01 	 96 	 97 	 2.040816
# Scaffold_01 	 119 	 120 	 0.000000
# Scaffold_01 	 193 	 194 	 0.000000
# Scaffold_01 	 202 	 203 	 0.000000
# Scaffold_01 	 209 	 210 	 0.000000
# Scaffold_01 	 213 	 214 	 0.000000
# Scaffold_01 	 221 	 222 	 0.000000
# Scaffold_01 	 238 	 239 	 1.315789
# awk: write error on /dev/stdout
#  input record number 1533, file
#  source line number 1
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# sed: stdout: Broken pipe
# cat: stdout: Broken pipe

# %%
# !cat /Volumes/Serine/wd/19-11-05/PgALL.74.CpG_report.merged_CpG_evidence.cov \
| sed 's/PGA_scaffold10__49_contigs__length_53961475/Scaffold_10/g' \
| sed 's/PGA_scaffold11__79_contigs__length_51449921/Scaffold_11/g' \
| sed 's/PGA_scaffold12__71_contigs__length_50438331/Scaffold_12/g' \
| sed 's/PGA_scaffold13__52_contigs__length_44396874/Scaffold_13/g' \
| sed 's/PGA_scaffold14__91_contigs__length_45393038/Scaffold_14/g' \
| sed 's/PGA_scaffold15__101_contigs__length_47938513/Scaffold_15/g' \
| sed 's/PGA_scaffold16__33_contigs__length_31980953/Scaffold_16/g' \
| sed 's/PGA_scaffold17__51_contigs__length_34923512/Scaffold_17/g' \
| sed 's/PGA_scaffold18__69_contigs__length_27737463/Scaffold_18/g' \
| sed 's/PGA_scaffold1__77_contigs__length_89643857/Scaffold_01/g' \
| sed 's/PGA_scaffold2__36_contigs__length_69596280/Scaffold_02/g' \
| sed 's/PGA_scaffold3__111_contigs__length_57743597/Scaffold_03/g' \
| sed 's/PGA_scaffold4__129_contigs__length_65288255/Scaffold_04/g' \
| sed 's/PGA_scaffold5__109_contigs__length_67248332/Scaffold_05/g' \
| sed 's/PGA_scaffold6__104_contigs__length_61759565/Scaffold_06/g' \
| sed 's/PGA_scaffold7__69_contigs__length_43120122/Scaffold_07/g' \
| sed 's/PGA_scaffold8__63_contigs__length_61151155/Scaffold_08/g' \
| sed 's/PGA_scaffold9__45_contigs__length_38581958/Scaffold_09/g' \
| awk '{if ($5+$6 >= 10) { print $1, "\t", $2, "\t", $3, "\t", $4}}' \
> analyses/PgALL.bed

# %%
ls analyses/
# Out:
# 0225_igv_session.xml
# 0817_GO-annot.tab
# 0821_GO-annot.tab
# 1023_GO-annot.tab
# 50p_intersect_exon_u.txt
# 50p_intersect_intron_u.txt
# 50p_intersect_rm_u.txt
# 5xbedgraph.zip
# EPI-103_S27_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# EPI-103_S27_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov.destrand.10x.bedgraph
# EPI-103_S27_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov.destrand.5x.bedgraph
# EPI-103_S27_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov_10x.bedgraph
# EPI-104_S28_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# EPI-104_S28_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov.destrand.10x.bedgraph
# EPI-104_S28_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov.destrand.5x.bedgraph
# EPI-104_S28_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov_10x.bedgraph
# EPI-111_S29_L005_R1_001_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# ...

# %%
# !ls -l -h analyses/PgALL.bed
# Out:
# ls: analyses/PgALL.bed: No such file or directory

# %% [markdown]
# https://d.pr/f/O5Dg5b
